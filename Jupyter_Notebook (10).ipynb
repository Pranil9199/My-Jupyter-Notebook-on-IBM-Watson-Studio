# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **PRANIL WAGHMARE** I am a student , & i want be a data scientist

# %% [markdown]
# *I am interested in data science because it is interesting, and i will love to work with data*

# %% [markdown]
# ### In following code show the Addition of two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# https://labs.cognitiveclass.ai/v2/tools/jupyterlab?ulid=ulid-78f1b366d66d4712141e259f1365edbaf01e32a8

# %% [markdown]
# 1.
# 2.
# 3.

# %% [markdown]
# ![photo-1605559424843-9e4c228bf1c2.jpg](attachment:86330999-caab-4979-849f-70c02ea43a17.jpg)
